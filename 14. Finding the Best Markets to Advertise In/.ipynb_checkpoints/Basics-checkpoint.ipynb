# %% [markdown]
# # Finding the Best Markets to Advertise In

# %% [markdown]
# We're working for an an e-learning company that offers courses on programming. Most of our courses are on web and mobile development, but we also cover many other domains, like data science, game development, etc. We want to promote our product and we'd like to invest some money in advertisement. Our goal in this project is to find out the two best markets to advertise our product in.

# %% [markdown]
# ## Slide 2 of 8

# %%
import pandas as pd
import numpy as np

survey = pd.read_csv('2017-fCC-New-Coders-Survey-Data.csv')
survey.head(5)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (17,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls         ...           \
# 0                   NaN                   NaN         ...
# 1                   NaN                   NaN         ...
# 2                   NaN                   NaN         ...
# 3                   NaN                   NaN         ...
# 4                   NaN                   NaN         ...
#
#    YouTubeFCC  YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0         NaN                    NaN               NaN               NaN
# 1         1.0                    NaN               NaN               NaN
# 2         NaN                    NaN               NaN               1.0
# 3         1.0                    1.0               NaN               NaN
# 4         NaN                    NaN               NaN               NaN
#
#    YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                 NaN         NaN                  NaN          NaN
# 1                 NaN         NaN                  NaN          NaN
# 2                 1.0         NaN                  NaN          NaN
# 3                 1.0         NaN                  NaN          NaN
# 4                 NaN         NaN                  NaN          NaN
#
#    YouTubeSimplilearn  YouTubeTheNewBoston
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 136 columns]

# %%
survey.columns.values
# Out:
# array(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber',
#        'CityPopulation', 'CodeEventConferences', 'CodeEventDjangoGirls',
#        'CodeEventFCC', 'CodeEventGameJam', 'CodeEventGirlDev',
#        'CodeEventHackathons', 'CodeEventMeetup', 'CodeEventNodeSchool',
#        'CodeEventNone', 'CodeEventOther', 'CodeEventRailsBridge',
#        'CodeEventRailsGirls', 'CodeEventStartUpWknd',
#        'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen',
#        'CountryLive', 'EmploymentField', 'EmploymentFieldOther',
#        'EmploymentStatus', 'EmploymentStatusOther', 'ExpectedEarning',
#        'FinanciallySupporting', 'FirstDevJob', 'Gender', 'GenderOther',
#        'HasChildren', 'HasDebt', 'HasFinancialDependents',
#        'HasHighSpdInternet', 'HasHomeMortgage', 'HasServedInMilitary',
#        'HasStudentDebt', 'HomeMortgageOwe', 'HoursLearning', 'ID.x',
#        'ID.y', 'Income', 'IsEthnicMinority',
#        'IsReceiveDisabilitiesBenefits', 'IsSoftwareDev',
#        'IsUnderEmployed', 'JobApplyWhen', 'JobInterestBackEnd',
#        'JobInterestDataEngr', 'JobInterestDataSci', 'JobInterestDevOps',
#        'JobInterestFrontEnd', 'JobInterestFullStack',
#        'JobInterestGameDev', 'JobInterestInfoSec', 'JobInterestMobile',
#        'JobInterestOther', 'JobInterestProjMngr', 'JobInterestQAEngr',
#        'JobInterestUX', 'JobPref', 'JobRelocateYesNo', 'JobRoleInterest',
#        'JobWherePref', 'LanguageAtHome', 'MaritalStatus',
#        'MoneyForLearning', 'MonthsProgramming', 'NetworkID',
#        'Part1EndTime', 'Part1StartTime', 'Part2EndTime', 'Part2StartTime',
#        'PodcastChangeLog', 'PodcastCodeNewbie', 'PodcastCodePen',
#        'PodcastDevTea', 'PodcastDotNET', 'PodcastGiantRobots',
#        'PodcastJSAir', 'PodcastJSJabber', 'PodcastNone', 'PodcastOther',
#        'PodcastProgThrowdown', 'PodcastRubyRogues', 'PodcastSEDaily',
#        'PodcastSERadio', 'PodcastShopTalk', 'PodcastTalkPython',
#        'PodcastTheWebAhead', 'ResourceCodecademy', 'ResourceCodeWars',
#        'ResourceCoursera', 'ResourceCSS', 'ResourceEdX',
#        'ResourceEgghead', 'ResourceFCC', 'ResourceHackerRank',
#        'ResourceKA', 'ResourceLynda', 'ResourceMDN', 'ResourceOdinProj',
#        'ResourceOther', 'ResourcePluralSight', 'ResourceSkillcrush',
#        'ResourceSO', 'ResourceTreehouse', 'ResourceUdacity',
#        'ResourceUdemy', 'ResourceW3S', 'SchoolDegree', 'SchoolMajor',
#        'StudentDebtOwe', 'YouTubeCodeCourse', 'YouTubeCodingTrain',
#        'YouTubeCodingTut360', 'YouTubeComputerphile', 'YouTubeDerekBanas',
#        'YouTubeDevTips', 'YouTubeEngineeredTruth', 'YouTubeFCC',
#        'YouTubeFunFunFunction', 'YouTubeGoogleDev', 'YouTubeLearnCode',
#        'YouTubeLevelUpTuts', 'YouTubeMIT', 'YouTubeMozillaHacks',
#        'YouTubeOther', 'YouTubeSimplilearn', 'YouTubeTheNewBoston'],
#       dtype=object)

# %%
survey.describe()
# Out:
#                 Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# count  15367.000000      17709.000000     1069.000000        1079.000000
# mean      27.691872          0.062002        0.699719           0.305839
# std        8.559239          0.241167        0.458594           0.460975
# min        0.000000          0.000000        0.000000           0.000000
# 25%       22.000000          0.000000        0.000000           0.000000
# 50%       26.000000          0.000000        1.000000           0.000000
# 75%       32.000000          0.000000        1.000000           1.000000
# max       90.000000          1.000000        1.000000           1.000000
#
#        BootcampRecommend  ChildrenNumber  CodeEventConferences  \
# count        1073.000000     2314.000000                1609.0
# mean            0.818267        1.832325                   1.0
# std             0.385805        0.972813                   0.0
# min             0.000000        1.000000                   1.0
# 25%             1.000000        1.000000                   1.0
# 50%             1.000000        2.000000                   1.0
# 75%             1.000000        2.000000                   1.0
# max             1.000000        9.000000                   1.0
#
#        CodeEventDjangoGirls  CodeEventFCC  CodeEventGameJam  \
# count                 165.0        1708.0             290.0
# mean                    1.0           1.0               1.0
# std                     0.0           0.0               0.0
# min                     1.0           1.0               1.0
# 25%                     1.0           1.0               1.0
# 50%                     1.0           1.0               1.0
# 75%                     1.0           1.0               1.0
# max                     1.0           1.0               1.0
#
#               ...           YouTubeEngineeredTruth  YouTubeFCC  \
# count         ...                            993.0      6036.0
# mean          ...                              1.0         1.0
# std           ...                              0.0         0.0
# min           ...                              1.0         1.0
# 25%           ...                              1.0         1.0
# 50%           ...                              1.0         1.0
# 75%           ...                              1.0         1.0
# max           ...                              1.0         1.0
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# count                 1261.0            3539.0            2662.0
# mean                     1.0               1.0               1.0
# std                      0.0               0.0               0.0
# min                      1.0               1.0               1.0
# 25%                      1.0               1.0               1.0
# 50%                      1.0               1.0               1.0
# 75%                      1.0               1.0               1.0
# max                      1.0               1.0               1.0
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks  \
# count              1396.0      3327.0                622.0
# mean                  1.0         1.0                  1.0
# std                   0.0         0.0                  0.0
# min                   1.0         1.0                  1.0
# 25%                   1.0         1.0                  1.0
# 50%                   1.0         1.0                  1.0
# 75%                   1.0         1.0                  1.0
# max                   1.0         1.0                  1.0
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# count               201.0               2960.0
# mean                  1.0                  1.0
# std                   0.0                  0.0
# min                   1.0                  1.0
# 25%                   1.0                  1.0
# 50%                   1.0                  1.0
# 75%                   1.0                  1.0
# max                   1.0                  1.0
#
# [8 rows x 105 columns]

# %% [markdown]
# To reach our goal, we could organize surveys for a couple of different markets to find out which would the best choices for advertising. This is very costly, however, and it's a good call to explore cheaper options first.
#
# This data set has some information about the behaviours of the freecodecamp survey participats, their demographics, and what platforms they use to learn coding and what general areas they want to code in.
#
# The data can be downloaded from [2107 freecodecamp survey](https://github.com/freeCodeCamp/2017-new-coder-survey)

# %% [markdown]
# ## slide 3:
# Answering questions about a "population" of new codres.
# First we need to find out if the sample we have is represntativ of the population

# %%
##Generating a frequency  distribution table for JobRoleInterest column in percentages
import pprint

freq_table = survey['JobRoleInterest'].value_counts(normalize = True)*100

freq_table
# Out:
# Full-Stack Web Developer                                                                                                                                                                                                                                                    11.770595
#   Front-End Web Developer                                                                                                                                                                                                                                                    6.435927
#   Data Scientist                                                                                                                                                                                                                                                             2.173913
# Back-End Web Developer                                                                                                                                                                                                                                                       2.030892
#   Mobile Developer                                                                                                                                                                                                                                                           1.673341
# Game Developer                                                                                                                                                                                                                                                               1.630435
# Information Security                                                                                                                                                                                                                                                         1.315789
# Full-Stack Web Developer,   Front-End Web Developer                                                                                                                                                                                                                          0.915332
#   Front-End Web Developer, Full-Stack Web Developer                                                                                                                                                                                                                          0.800915
#   Product Manager                                                                                                                                                                                                                                                            0.786613
# Data Engineer                                                                                                                                                                                                                                                                0.758009
#   User Experience Designer                                                                                                                                                                                                                                                   0.743707
#   User Experience Designer,   Front-End Web Developer                                                                                                                                                                                                                        0.614989
#   Front-End Web Developer, Back-End Web Developer, Full-Stack Web Developer                                                                                                                                                                                                  0.557780
# Back-End Web Developer,   Front-End Web Developer, Full-Stack Web Developer                                                                                                                                                                                                  0.514874
#   DevOps / SysAdmin                                                                                                                                                                                                                                                          0.514874
# Back-End Web Developer, Full-Stack Web Developer,   Front-End Web Developer                                                                                                                                                                                                  0.514874
# Full-Stack Web Developer,   Front-End Web Developer, Back-End Web Developer                                                                                                                                                                                                  0.443364
#   Front-End Web Developer, Full-Stack Web Developer, Back-End Web Developer                                                                                                                                                                                                  0.429062
#   Front-End Web Developer,   User Experience Designer                                                                                                                                                                                                                        0.414760
# Full-Stack Web Developer,   Mobile Developer                                                                                                                                                                                                                                 0.414760
# Back-End Web Developer, Full-Stack Web Developer                                                                                                                                                                                                                             0.386156
# Full-Stack Web Developer, Back-End Web Developer                                                                                                                                                                                                                             0.371854
# Back-End Web Developer,   Front-End Web Developer                                                                                                                                                                                                                            0.286041
# Data Engineer,   Data Scientist                                                                                                                                                                                                                                              0.271739
# Full-Stack Web Developer, Back-End Web Developer,   Front-End Web Developer                                                                                                                                                                                                  0.271739
#   Front-End Web Developer,   Mobile Developer                                                                                                                                                                                                                                0.257437
# Full-Stack Web Developer,   Data Scientist                                                                                                                                                                                                                                   0.243135
#   Data Scientist, Data Engineer                                                                                                                                                                                                                                              0.228833
#   Mobile Developer, Game Developer                                                                                                                                                                                                                                           0.228833
#                                                                                                                                                                                                                                                                               ...
#   Mobile Developer,   Front-End Web Developer, Full-Stack Web Developer, Journalist/Graphic Designer/Marketing                                                                                                                                                               0.014302
# Full-Stack Web Developer,   Mobile Developer,   User Experience Designer, Game Developer,   Front-End Web Developer, Information Security                                                                                                                                    0.014302
#   Front-End Web Developer, Back-End Web Developer, Full-Stack Web Developer, Game Developer,   Mobile Developer                                                                                                                                                              0.014302
# Game Developer,   User Experience Designer, Information Security,   DevOps / SysAdmin                                                                                                                                                                                        0.014302
#   DevOps / SysAdmin, Data Engineer,   Data Scientist, Game Developer, Full-Stack Web Developer,   Mobile Developer,   Front-End Web Developer, Back-End Web Developer,   User Experience Designer, Information Security                                                      0.014302
# programmer                                                                                                                                                                                                                                                                   0.014302
# Data Engineer, Full-Stack Web Developer                                                                                                                                                                                                                                      0.014302
# Full-Stack Web Developer,   Data Scientist, Information Security,   Mobile Developer, Data Engineer,   Quality Assurance Engineer, Game Developer                                                                                                                            0.014302
# Back-End Web Developer,   Data Scientist, Game Developer, Data Engineer, Full-Stack Web Developer,   User Experience Designer                                                                                                                                                0.014302
#   User Experience Designer, Back-End Web Developer,   Front-End Web Developer,   DevOps / SysAdmin, Information Security, Full-Stack Web Developer,   Mobile Developer                                                                                                       0.014302
#   Data Scientist, Full-Stack Web Developer,   Product Manager                                                                                                                                                                                                                0.014302
#   Front-End Web Developer, Python Developer                                                                                                                                                                                                                                  0.014302
# Back-End Web Developer, Data Engineer,   Quality Assurance Engineer,   Front-End Web Developer, Full-Stack Web Developer, Information Security,   Product Manager,   Data Scientist,   Mobile Developer,   User Experience Designer, Game Developer,   DevOps / SysAdmin     0.014302
# Back-End Web Developer, Data Engineer,   Mobile Developer, Information Security,   Front-End Web Developer, Full-Stack Web Developer                                                                                                                                         0.014302
#   Product Manager,   Data Scientist,   User Experience Designer,   Front-End Web Developer                                                                                                                                                                                   0.014302
#   Data Scientist, Data Engineer,   Product Manager, Back-End Web Developer                                                                                                                                                                                                   0.014302
# Full-Stack Web Developer,   Mobile Developer,   Data Scientist, Game Developer, Back-End Web Developer                                                                                                                                                                       0.014302
#   Data Scientist,   Product Manager,   Mobile Developer, Back-End Web Developer,   Front-End Web Developer, Full-Stack Web Developer, Game Developer                                                                                                                         0.014302
#   Product Manager,   User Experience Designer,   Mobile Developer, Full-Stack Web Developer, Game Developer, Back-End Web Developer, Data Engineer,   Front-End Web Developer,   Data Scientist                                                                              0.014302
# Full-Stack Web Developer,   User Experience Designer,   Front-End Web Developer, Back-End Web Developer,   Data Scientist, Data Engineer                                                                                                                                     0.014302
#   Mobile Developer, Full-Stack Web Developer,   Front-End Web Developer,   DevOps / SysAdmin, Back-End Web Developer                                                                                                                                                         0.014302
#   Mobile Developer, Back-End Web Developer, Information Security,   DevOps / SysAdmin                                                                                                                                                                                        0.014302
#   Front-End Web Developer,   Mobile Developer,   Product Manager,   DevOps / SysAdmin, Full-Stack Web Developer, Game Developer, Back-End Web Developer                                                                                                                      0.014302
# Back-End Web Developer,   Mobile Developer, Full-Stack Web Developer,   Front-End Web Developer,   Product Manager,   User Experience Designer                                                                                                                               0.014302
#   Front-End Web Developer, Game Developer,   Mobile Developer, Back-End Web Developer, Information Security,   DevOps / SysAdmin,   Data Scientist,   Product Manager                                                                                                        0.014302
#   Product Manager,   Mobile Developer, Game Developer, Software enginner                                                                                                                                                                                                     0.014302
# Game Developer, Back-End Web Developer,   DevOps / SysAdmin, Information Security,   Front-End Web Developer, Data Engineer,   Quality Assurance Engineer,   Mobile Developer                                                                                                0.014302
#   DevOps / SysAdmin, Information Security,   Mobile Developer, Back-End Web Developer                                                                                                                                                                                        0.014302
# Game Developer, Full-Stack Web Developer,   Data Scientist, Data Engineer                                                                                                                                                                                                    0.014302
#   DevOps / SysAdmin,   Front-End Web Developer, Full-Stack Web Developer, Back-End Web Developer                                                                                                                                                                             0.014302
# Name: JobRoleInterest, Length: 3213, dtype: float64

# %% [markdown]
# People can definitly be interested in more than one subject only 30% of the people are interested in one subject.
#
# Yes, it should be representative of a population
#
#
# Full-Stack Web Developer                                                                                                                                                                      11.770595
# Front-End Web Developer                                                                                                                                                                      6.435927
# Back-End Web Developer                                                                                                                                                                         2.030892
# Mobile Developer                                                                        1.673341%

# %%
#Since the number of combinations is really high we need to split these:
    
# Split each string in the 'JobRoleInterest' column
interests_no_nulls = survey['JobRoleInterest'].dropna() #dropping the non-numbered values
splitted_interests = interests_no_nulls.str.split(',') #splitting the various interests by ','

# Frequency table for the var describing the number of options
n_of_options = splitted_interests.apply(lambda x: len(x)) # x is a list of job options
n_of_options.value_counts(normalize = True).sort_index() * 100
# Out:
# 1     31.650458
# 2     10.883867
# 3     15.889588
# 4     15.217391
# 5     12.042334
# 6      6.721968
# 7      3.861556
# 8      1.759153
# 9      0.986842
# 10     0.471968
# 11     0.185927
# 12     0.300343
# 13     0.028604
# Name: JobRoleInterest, dtype: float64

# %% [markdown]
# This means that only 32% of the people have chosen one option. veryone else has chosen more than one option.

# %%
## need to find out who like web development (all combinations) and Mobile Development

web_mobile_dev = interests_no_nulls.str.contains("Web Developer|Mobile Developer") #boolean array showing if it contains the strings or not

WMD_freq_table = web_mobile_dev.value_counts(normalize = True) * 100
print(WMD_freq_table)
# Out:
# True     86.241419
# False    13.758581
# Name: JobRoleInterest, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

#plt.style.use('fivethirtyeight')
WMD_freq_table.plot.bar()

plt.title('Coparison of Participants Interested in \nWeb or Mobile Development, on their own or maongst other things',
          y = 1.08) # y pads the title upward
plt.ylabel('Percentage', fontsize = 12)
plt.xticks([0,1],['Web or mobile\ndevelopment', 'Just Others'],
           rotation = 0) # the initial xtick labels were True and False
plt.ylim([0,100])
plt.show()

# %% [markdown]
# As we can see in the graph above, the percetage of people who would like ot to Web and mobile app development or a combination of these (includes fornt end, back end and full stack) is more than 80%). This means that this sample is representativ eof out population of interest. And it also generally shows that we are on track for advertising in these two fields because most people want to have these types of skills. It has to be pointed ut that the 80+% is not representative of the whole survey, some pople may have not answered anything for that column (NaN). Thos epople have been removed already so we could do the calculation.

# %% [markdown]
# ## Slide 4 of 8
#
# We will use the "interests_no_nulls" variable already made above, because we are not sure of what they want and that can affect our results.

# %%
df_interest_notnull = survey[survey['JobRoleInterest'].notnull()]

abs_freq_country = df_interest_notnull["CountryLive"].value_counts()
rel_freq_country = df_interest_notnull["CountryLive"].value_counts(normalize = True)*100

df2 = pd.DataFrame(data ={"abs_countries":abs_freq_country,"%relative_countries": rel_freq_country})

# print(abs_freq_country.head(10))
# print("\n")
# print(rel_freq_country.head(10))
df2
# Out:
#                                %relative_countries  abs_countries
# United States of America                 45.700497           3125
# India                                     7.721556            528
# United Kingdom                            4.606610            315
# Canada                                    3.802281            260
# Poland                                    1.915765            131
# Brazil                                    1.886517            129
# Germany                                   1.828020            125
# Australia                                 1.637906            112
# Russia                                    1.491664            102
# Ukraine                                   1.301550             89
# Nigeria                                   1.228429             84
# Spain                                     1.126060             77
# France                                    1.096812             75
# Romania                                   1.038315             71
# Netherlands (Holland, Europe)             0.950570             65
# Italy                                     0.906698             62
# Philippines                               0.760456             52
# Serbia                                    0.760456             52
# Greece                                    0.672711             46
# Ireland                                   0.628839             43
# South Africa                              0.570342             39
# Mexico                                    0.541094             37
# Turkey                                    0.526470             36
# Hungary                                   0.497221             34
# Singapore                                 0.497221             34
# New Zealand                               0.482597             33
# Croatia                                   0.467973             32
# Argentina                                 0.467973             32
# Indonesia                                 0.453349             31
# Pakistan                                  0.453349             31
# ...                                            ...            ...
# Turkmenistan                              0.014624              1
# Angola                                    0.014624              1
# Kyrgyzstan                                0.014624              1
# Liberia                                   0.014624              1
# Channel Islands                           0.014624              1
# Vanuatu                                   0.014624              1
# Cayman Islands                            0.014624              1
# Rwanda                                    0.014624              1
# Qatar                                     0.014624              1
# Trinidad & Tobago                         0.014624              1
# Guatemala                                 0.014624              1
# Somalia                                   0.014624              1
# Anguilla                                  0.014624              1
# Panama                                    0.014624              1
# Botswana                                  0.014624              1
# Papua New Guinea                          0.014624              1
# Gibraltar                                 0.014624              1
# Mozambique                                0.014624              1
# Bolivia                                   0.014624              1
# Jordan                                    0.014624              1
# Cameroon                                  0.014624              1
# Nicaragua                                 0.014624              1
# Guadeloupe                                0.014624              1
# Sudan                                     0.014624              1
# Yemen                                     0.014624              1
# Myanmar                                   0.014624              1
# Samoa                                     0.014624              1
# Aruba                                     0.014624              1
# Cuba                                      0.014624              1
# Nambia                                    0.014624              1
#
# [137 rows x 2 columns]

# %% [markdown]
# Around 45% of the people who are interested in some sort of a job role are form the USA, the second country represented is India with 7.7% of the people. So if we were to advertise, we have to go to USA and India.
#
# We should go more in depth. We can look at age, or how much they have spent on learning coding or what they expect to get out of it in terms of renumeration.

# %% [markdown]
# ## Slide 5 of 8
# Need to find out the amoount money each student spends per month.
# Also, 4 countries (the top 4 form the previous list), and they all have Eglish. With that we have around 61% of the resondents who are interested in som eform of job role form the survey. Around 4100 people in total.

# %%
# Replace 0s with 1s to avoid division by 0
df_interest_notnull['MonthsProgramming'].replace(0,1, inplace = True)

#Do a division to find hte vlau for the new clumn, we alreay replaced zeros with 1 to avoid inf values.
df_interest_notnull["AmountPerMonth"] = df_interest_notnull["MoneyForLearning"]/df_interest_notnull["MonthsProgramming"]

df_interest_notnull["AmountPerMonth"].isnull().sum() # There are 676 values that are null in this case
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 675

# %%
#Keep only the rows that don't have a null value for the Amount per month column.
df_interest_notnull2 = df_interest_notnull[df_interest_notnull["AmountPerMonth"].notnull()]

#Remove also any rows that have null values in the CountryLive column.

df_interest_notnull2 = df_interest_notnull2[df_interest_notnull2["CountryLive"].notnull()]

Grouped_country = df_interest_notnull2.groupby(["CountryLive"]).mean()

Top_4 = Grouped_country["AmountPerMonth"].loc[["Canada", "United States of America","India","United Kingdom"]]

# %%
#As a summary metric, we recommend choosing the mean to take into account all values in
#the distributions. You can also compute the median or the mode to see how they compare with the mean.


Grouped_country
# Out:
#                                 Age  AttendedBootcamp  BootcampFinish  \
# CountryLive
# Afghanistan               18.750000          0.000000             NaN
# Albania                   20.666667          0.000000             NaN
# Algeria                   23.750000          0.000000             NaN
# Angola                    20.000000          0.000000             NaN
# Anguilla                  25.000000               NaN             NaN
# Argentina                 26.466667          0.000000             NaN
# Australia                 28.465347          0.068627        0.142857
# Austria                   26.500000          0.062500        0.000000
# Azerbaijan                27.666667          0.000000             NaN
# Bahrain                   14.000000          0.000000             NaN
# Bangladesh                24.277778          0.000000             NaN
# Belarus                   25.333333          0.000000             NaN
# Belgium                   27.705882          0.000000             NaN
# Bosnia & Herzegovina      26.050000          0.050000        1.000000
# Botswana                  23.000000          0.000000             NaN
# Brazil                    24.783784          0.000000             NaN
# Bulgaria                  25.357143          0.000000             NaN
# Cambodia                  22.000000          0.000000             NaN
# Cameroon                  21.000000          0.000000             NaN
# Canada                    26.924686          0.037657        0.625000
# Cayman Islands            20.000000          0.000000             NaN
# Channel Islands                 NaN          0.000000             NaN
# Chile                     24.200000          0.000000             NaN
# China                     25.600000          0.000000             NaN
# Colombia                  23.142857          0.000000             NaN
# Costa Rica                22.833333          0.000000             NaN
# Croatia                   28.692308          0.000000             NaN
# Cuba                      26.000000          0.000000             NaN
# Cyprus                    36.000000          0.000000             NaN
# Czech Republic            23.615385          0.000000             NaN
# ...                             ...               ...             ...
# Senegal                   34.500000          0.000000             NaN
# Serbia                    28.113636          0.000000             NaN
# Singapore                 24.793103          0.034483        0.000000
# Slovakia                  24.428571          0.000000             NaN
# Slovenia                  27.666667          0.000000             NaN
# Somalia                   34.000000          0.000000             NaN
# South Africa              27.944444          0.027778        0.000000
# Spain                     28.200000          0.106061        0.428571
# Sri Lanka                 24.000000          0.125000        0.000000
# Sweden                    25.370370          0.000000             NaN
# Switzerland               29.214286          0.000000             NaN
# Taiwan                    31.166667          0.166667        0.500000
# Thailand                  23.900000          0.000000             NaN
# Trinidad & Tobago         37.000000          0.000000             NaN
# Tunisia                   21.000000          0.200000        1.000000
# Turkey                    24.612903          0.000000             NaN
# Turkmenistan              17.000000          0.000000             NaN
# Uganda                    26.666667          0.000000             NaN
# Ukraine                   25.797468          0.038462        0.000000
# United Arab Emirates      25.062500          0.000000             NaN
# United Kingdom            28.620939          0.025090        0.714286
# United States of America  29.382282          0.081877        0.529661
# Uruguay                   30.500000          0.000000             NaN
# Uzbekistan                21.333333          0.000000             NaN
# Vanuatu                   28.000000          0.000000             NaN
# Venezuela                 23.384615          0.000000             NaN
# Vietnam                   22.291667          0.000000             NaN
# Virgin Islands (USA)      36.166667          0.000000             NaN
# Yemen                      1.000000          0.000000             NaN
# Zimbabwe                  28.750000          0.000000             NaN
#
#                           BootcampLoanYesNo  BootcampRecommend  \
# CountryLive
# Afghanistan                             NaN                NaN
# Albania                                 NaN                NaN
# Algeria                                 NaN                NaN
# Angola                                  NaN                NaN
# Anguilla                                NaN                NaN
# Argentina                               NaN                NaN
# Australia                          0.428571           0.857143
# Austria                            0.000000           1.000000
# Azerbaijan                              NaN                NaN
# Bahrain                                 NaN                NaN
# Bangladesh                              NaN                NaN
# Belarus                                 NaN                NaN
# Belgium                                 NaN                NaN
# Bosnia & Herzegovina               1.000000           0.000000
# Botswana                                NaN                NaN
# Brazil                                  NaN                NaN
# Bulgaria                                NaN                NaN
# Cambodia                                NaN                NaN
# Cameroon                                NaN                NaN
# Canada                             0.222222           0.555556
# Cayman Islands                          NaN                NaN
# Channel Islands                         NaN                NaN
# Chile                                   NaN                NaN
# China                                   NaN                NaN
# Colombia                                NaN                NaN
# Costa Rica                              NaN                NaN
# Croatia                                 NaN                NaN
# Cuba                                    NaN                NaN
# Cyprus                                  NaN                NaN
# Czech Republic                          NaN                NaN
# ...                                     ...                ...
# Senegal                                 NaN                NaN
# Serbia                                  NaN                NaN
# Singapore                          0.000000           1.000000
# Slovakia                                NaN                NaN
# Slovenia                                NaN                NaN
# Somalia                                 NaN                NaN
# South Africa                       0.000000           0.000000
# Spain                              0.714286           0.857143
# Sri Lanka                          0.000000           1.000000
# Sweden                                  NaN                NaN
# Switzerland                             NaN                NaN
# Taiwan                             0.500000           0.500000
# Thailand                                NaN                NaN
# Trinidad & Tobago                       NaN                NaN
# Tunisia                            0.000000           1.000000
# Turkey                                  NaN                NaN
# Turkmenistan                            NaN                NaN
# Uganda                                  NaN                NaN
# Ukraine                            0.333333           1.000000
# United Arab Emirates                    NaN                NaN
# United Kingdom                     0.571429           0.857143
# United States of America           0.341772           0.772152
# Uruguay                                 NaN                NaN
# Uzbekistan                              NaN                NaN
# Vanuatu                                 NaN                NaN
# Venezuela                               NaN                NaN
# Vietnam                                 NaN                NaN
# Virgin Islands (USA)                    NaN                NaN
# Yemen                                   NaN                NaN
# Zimbabwe                                NaN                NaN
#
#                           ChildrenNumber  CodeEventConferences  \
# CountryLive
# Afghanistan                          NaN                   1.0
# Albania                              NaN                   NaN
# Algeria                              NaN                   NaN
# Angola                               NaN                   1.0
# Anguilla                        2.000000                   NaN
# Argentina                       1.166667                   1.0
# Australia                       1.714286                   1.0
# Austria                         2.000000                   1.0
# Azerbaijan                      1.000000                   NaN
# Bahrain                              NaN                   NaN
# Bangladesh                      2.000000                   1.0
# Belarus                         1.500000                   1.0
# Belgium                         1.500000                   1.0
# Bosnia & Herzegovina                 NaN                   NaN
# Botswana                             NaN                   NaN
# Brazil                          1.555556                   1.0
# Bulgaria                             NaN                   1.0
# Cambodia                             NaN                   1.0
# Cameroon                             NaN                   NaN
# Canada                          1.888889                   1.0
# Cayman Islands                       NaN                   NaN
# Channel Islands                      NaN                   NaN
# Chile                           1.000000                   NaN
# China                           1.000000                   1.0
# Colombia                        1.000000                   1.0
# Costa Rica                           NaN                   1.0
# Croatia                         1.500000                   1.0
# Cuba                                 NaN                   NaN
# Cyprus                               NaN                   NaN
# Czech Republic                  2.000000                   1.0
# ...                                  ...                   ...
# Senegal                         4.000000                   NaN
# Serbia                          1.600000                   1.0
# Singapore                       1.500000                   1.0
# Slovakia                             NaN                   NaN
# Slovenia                        2.500000                   1.0
# Somalia                              NaN                   NaN
# South Africa                    1.555556                   1.0
# Spain                           1.200000                   1.0
# Sri Lanka                            NaN                   1.0
# Sweden                          1.000000                   1.0
# Switzerland                     1.000000                   1.0
# Taiwan                          2.333333                   NaN
# Thailand                        3.000000                   1.0
# Trinidad & Tobago                    NaN                   NaN
# Tunisia                              NaN                   NaN
# Turkey                               NaN                   1.0
# Turkmenistan                         NaN                   NaN
# Uganda                               NaN                   NaN
# Ukraine                         2.200000                   1.0
# United Arab Emirates            2.000000                   1.0
# United Kingdom                  1.833333                   1.0
# United States of America        1.918367                   1.0
# Uruguay                         2.000000                   NaN
# Uzbekistan                           NaN                   NaN
# Vanuatu                              NaN                   NaN
# Venezuela                            NaN                   1.0
# Vietnam                         1.000000                   NaN
# Virgin Islands (USA)                 NaN                   NaN
# Yemen                                NaN                   NaN
# Zimbabwe                        1.500000                   NaN
#
#                           CodeEventDjangoGirls  CodeEventFCC  \
# CountryLive
# Afghanistan                                NaN           NaN
# Albania                                    NaN           1.0
# Algeria                                    NaN           1.0
# Angola                                     NaN           1.0
# Anguilla                                   NaN           1.0
# Argentina                                  NaN           1.0
# Australia                                  NaN           1.0
# Austria                                    NaN           1.0
# Azerbaijan                                 NaN           NaN
# Bahrain                                    NaN           NaN
# Bangladesh                                 NaN           1.0
# Belarus                                    NaN           1.0
# Belgium                                    NaN           1.0
# Bosnia & Herzegovina                       NaN           1.0
# Botswana                                   NaN           NaN
# Brazil                                     1.0           1.0
# Bulgaria                                   NaN           NaN
# Cambodia                                   NaN           1.0
# Cameroon                                   NaN           NaN
# Canada                                     NaN           1.0
# Cayman Islands                             NaN           NaN
# Channel Islands                            NaN           NaN
# Chile                                      NaN           NaN
# China                                      NaN           1.0
# Colombia                                   NaN           1.0
# Costa Rica                                 NaN           NaN
# Croatia                                    1.0           1.0
# Cuba                                       NaN           NaN
# Cyprus                                     NaN           1.0
# Czech Republic                             1.0           1.0
# ...                                        ...           ...
# Senegal                                    NaN           NaN
# Serbia                                     NaN           1.0
# Singapore                                  NaN           NaN
# Slovakia                                   NaN           1.0
# Slovenia                                   NaN           NaN
# Somalia                                    NaN           1.0
# South Africa                               NaN           1.0
# Spain                                      1.0           1.0
# Sri Lanka                                  NaN           NaN
# Sweden                                     NaN           1.0
# Switzerland                                NaN           1.0
# Taiwan                                     1.0           1.0
# Thailand                                   NaN           NaN
# Trinidad & Tobago                          NaN           NaN
# Tunisia                                    NaN           1.0
# Turkey                                     NaN           1.0
# Turkmenistan                               NaN           1.0
# Uganda                                     NaN           1.0
# Ukraine                                    1.0           1.0
# United Arab Emirates                       1.0           1.0
# United Kingdom                             1.0           1.0
# United States of America                   1.0           1.0
# Uruguay                                    NaN           1.0
# Uzbekistan                                 NaN           1.0
# Vanuatu                                    NaN           1.0
# Venezuela                                  NaN           1.0
# Vietnam                                    1.0           1.0
# Virgin Islands (USA)                       NaN           1.0
# Yemen                                      NaN           NaN
# Zimbabwe                                   NaN           NaN
#
#                           CodeEventGameJam       ...        YouTubeFCC  \
# CountryLive                                      ...
# Afghanistan                            NaN       ...               1.0
# Albania                                NaN       ...               1.0
# Algeria                                NaN       ...               1.0
# Angola                                 1.0       ...               NaN
# Anguilla                               NaN       ...               NaN
# Argentina                              1.0       ...               1.0
# Australia                              NaN       ...               1.0
# Austria                                NaN       ...               1.0
# Azerbaijan                             NaN       ...               1.0
# Bahrain                                NaN       ...               NaN
# Bangladesh                             NaN       ...               1.0
# Belarus                                1.0       ...               1.0
# Belgium                                NaN       ...               1.0
# Bosnia & Herzegovina                   NaN       ...               1.0
# Botswana                               NaN       ...               1.0
# Brazil                                 1.0       ...               1.0
# Bulgaria                               NaN       ...               1.0
# Cambodia                               1.0       ...               1.0
# Cameroon                               NaN       ...               NaN
# Canada                                 1.0       ...               1.0
# Cayman Islands                         NaN       ...               NaN
# Channel Islands                        NaN       ...               1.0
# Chile                                  1.0       ...               1.0
# China                                  1.0       ...               1.0
# Colombia                               NaN       ...               1.0
# Costa Rica                             NaN       ...               1.0
# Croatia                                NaN       ...               1.0
# Cuba                                   NaN       ...               NaN
# Cyprus                                 NaN       ...               NaN
# Czech Republic                         NaN       ...               1.0
# ...                                    ...       ...               ...
# Senegal                                NaN       ...               1.0
# Serbia                                 NaN       ...               1.0
# Singapore                              NaN       ...               1.0
# Slovakia                               NaN       ...               1.0
# Slovenia                               NaN       ...               1.0
# Somalia                                NaN       ...               NaN
# South Africa                           1.0       ...               1.0
# Spain                                  1.0       ...               1.0
# Sri Lanka                              NaN       ...               1.0
# Sweden                                 NaN       ...               1.0
# Switzerland                            NaN       ...               1.0
# Taiwan                                 NaN       ...               1.0
# Thailand                               NaN       ...               1.0
# Trinidad & Tobago                      NaN       ...               NaN
# Tunisia                                NaN       ...               1.0
# Turkey                                 1.0       ...               1.0
# Turkmenistan                           NaN       ...               NaN
# Uganda                                 NaN       ...               1.0
# Ukraine                                1.0       ...               1.0
# United Arab Emirates                   1.0       ...               1.0
# United Kingdom                         1.0       ...               1.0
# United States of America               1.0       ...               1.0
# Uruguay                                NaN       ...               1.0
# Uzbekistan                             NaN       ...               1.0
# Vanuatu                                NaN       ...               1.0
# Venezuela                              NaN       ...               1.0
# Vietnam                                1.0       ...               1.0
# Virgin Islands (USA)                   NaN       ...               1.0
# Yemen                                  1.0       ...               NaN
# Zimbabwe                               NaN       ...               1.0
#
#                           YouTubeFunFunFunction  YouTubeGoogleDev  \
# CountryLive
# Afghanistan                                 NaN               NaN
# Albania                                     1.0               1.0
# Algeria                                     1.0               1.0
# Angola                                      NaN               NaN
# Anguilla                                    1.0               NaN
# Argentina                                   1.0               1.0
# Australia                                   1.0               1.0
# Austria                                     NaN               1.0
# Azerbaijan                                  NaN               NaN
# Bahrain                                     NaN               NaN
# Bangladesh                                  1.0               1.0
# Belarus                                     1.0               1.0
# Belgium                                     NaN               1.0
# Bosnia & Herzegovina                        1.0               1.0
# Botswana                                    NaN               NaN
# Brazil                                      1.0               1.0
# Bulgaria                                    NaN               1.0
# Cambodia                                    NaN               1.0
# Cameroon                                    1.0               NaN
# Canada                                      1.0               1.0
# Cayman Islands                              NaN               NaN
# Channel Islands                             NaN               1.0
# Chile                                       NaN               1.0
# China                                       1.0               1.0
# Colombia                                    1.0               1.0
# Costa Rica                                  NaN               1.0
# Croatia                                     1.0               1.0
# Cuba                                        NaN               1.0
# Cyprus                                      NaN               NaN
# Czech Republic                              1.0               1.0
# ...                                         ...               ...
# Senegal                                     NaN               1.0
# Serbia                                      1.0               1.0
# Singapore                                   NaN               1.0
# Slovakia                                    NaN               NaN
# Slovenia                                    1.0               1.0
# Somalia                                     NaN               NaN
# South Africa                                1.0               1.0
# Spain                                       1.0               1.0
# Sri Lanka                                   NaN               1.0
# Sweden                                      1.0               1.0
# Switzerland                                 1.0               1.0
# Taiwan                                      NaN               1.0
# Thailand                                    NaN               1.0
# Trinidad & Tobago                           NaN               1.0
# Tunisia                                     NaN               1.0
# Turkey                                      1.0               1.0
# Turkmenistan                                NaN               NaN
# Uganda                                      NaN               1.0
# Ukraine                                     1.0               1.0
# United Arab Emirates                        1.0               1.0
# United Kingdom                              1.0               1.0
# United States of America                    1.0               1.0
# Uruguay                                     NaN               NaN
# Uzbekistan                                  1.0               1.0
# Vanuatu                                     NaN               NaN
# Venezuela                                   1.0               1.0
# Vietnam                                     1.0               1.0
# Virgin Islands (USA)                        1.0               1.0
# Yemen                                       NaN               NaN
# Zimbabwe                                    NaN               1.0
#
#                           YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# CountryLive
# Afghanistan                            1.0                 NaN         NaN
# Albania                                1.0                 1.0         1.0
# Algeria                                1.0                 NaN         1.0
# Angola                                 1.0                 NaN         NaN
# Anguilla                               NaN                 NaN         NaN
# Argentina                              1.0                 NaN         1.0
# Australia                              1.0                 1.0         1.0
# Austria                                1.0                 NaN         1.0
# Azerbaijan                             1.0                 NaN         1.0
# Bahrain                                NaN                 NaN         NaN
# Bangladesh                             1.0                 1.0         1.0
# Belarus                                1.0                 1.0         1.0
# Belgium                                NaN                 NaN         1.0
# Bosnia & Herzegovina                   1.0                 1.0         1.0
# Botswana                               NaN                 NaN         NaN
# Brazil                                 1.0                 1.0         1.0
# Bulgaria                               1.0                 NaN         1.0
# Cambodia                               1.0                 NaN         NaN
# Cameroon                               NaN                 NaN         NaN
# Canada                                 1.0                 1.0         1.0
# Cayman Islands                         NaN                 NaN         NaN
# Channel Islands                        1.0                 NaN         NaN
# Chile                                  1.0                 NaN         1.0
# China                                  1.0                 NaN         1.0
# Colombia                               1.0                 NaN         1.0
# Costa Rica                             1.0                 NaN         1.0
# Croatia                                1.0                 1.0         1.0
# Cuba                                   NaN                 NaN         1.0
# Cyprus                                 NaN                 NaN         1.0
# Czech Republic                         1.0                 1.0         1.0
# ...                                    ...                 ...         ...
# Senegal                                NaN                 1.0         1.0
# Serbia                                 1.0                 1.0         1.0
# Singapore                              1.0                 NaN         1.0
# Slovakia                               NaN                 NaN         NaN
# Slovenia                               1.0                 NaN         1.0
# Somalia                                NaN                 NaN         NaN
# South Africa                           1.0                 1.0         1.0
# Spain                                  1.0                 1.0         1.0
# Sri Lanka                              1.0                 1.0         1.0
# Sweden                                 1.0                 1.0         1.0
# Switzerland                            1.0                 NaN         1.0
# Taiwan                                 1.0                 1.0         1.0
# Thailand                               NaN                 NaN         1.0
# Trinidad & Tobago                      1.0                 NaN         NaN
# Tunisia                                1.0                 NaN         NaN
# Turkey                                 1.0                 1.0         1.0
# Turkmenistan                           NaN                 NaN         NaN
# Uganda                                 1.0                 NaN         1.0
# Ukraine                                1.0                 1.0         1.0
# United Arab Emirates                   1.0                 1.0         1.0
# United Kingdom                         1.0                 1.0         1.0
# United States of America               1.0                 1.0         1.0
# Uruguay                                NaN                 NaN         NaN
# Uzbekistan                             NaN                 1.0         1.0
# Vanuatu                                NaN                 NaN         1.0
# Venezuela                              1.0                 1.0         1.0
# Vietnam                                1.0                 NaN         1.0
# Virgin Islands (USA)                   1.0                 1.0         1.0
# Yemen                                  NaN                 NaN         NaN
# Zimbabwe                               1.0                 NaN         NaN
#
#                           YouTubeMozillaHacks  YouTubeSimplilearn  \
# CountryLive
# Afghanistan                               NaN                 NaN
# Albania                                   NaN                 NaN
# Algeria                                   1.0                 NaN
# Angola                                    NaN                 NaN
# Anguilla                                  NaN                 NaN
# Argentina                                 NaN                 NaN
# Australia                                 1.0                 1.0
# Austria                                   NaN                 NaN
# Azerbaijan                                NaN                 NaN
# Bahrain                                   NaN                 NaN
# Bangladesh                                NaN                 NaN
# Belarus                                   1.0                 NaN
# Belgium                                   NaN                 NaN
# Bosnia & Herzegovina                      1.0                 NaN
# Botswana                                  NaN                 NaN
# Brazil                                    1.0                 1.0
# Bulgaria                                  NaN                 NaN
# Cambodia                                  NaN                 NaN
# Cameroon                                  NaN                 NaN
# Canada                                    1.0                 NaN
# Cayman Islands                            NaN                 NaN
# Channel Islands                           NaN                 NaN
# Chile                                     1.0                 NaN
# China                                     1.0                 NaN
# Colombia                                  1.0                 NaN
# Costa Rica                                NaN                 NaN
# Croatia                                   NaN                 NaN
# Cuba                                      NaN                 NaN
# Cyprus                                    NaN                 NaN
# Czech Republic                            NaN                 NaN
# ...                                       ...                 ...
# Senegal                                   NaN                 NaN
# Serbia                                    1.0                 NaN
# Singapore                                 NaN                 NaN
# Slovakia                                  NaN                 NaN
# Slovenia                                  NaN                 NaN
# Somalia                                   NaN                 NaN
# South Africa                              NaN                 1.0
# Spain                                     1.0                 1.0
# Sri Lanka                                 NaN                 1.0
# Sweden                                    1.0                 NaN
# Switzerland                               1.0                 NaN
# Taiwan                                    1.0                 NaN
# Thailand                                  1.0                 NaN
# Trinidad & Tobago                         NaN                 NaN
# Tunisia                                   1.0                 NaN
# Turkey                                    NaN                 NaN
# Turkmenistan                              NaN                 NaN
# Uganda                                    1.0                 NaN
# Ukraine                                   1.0                 NaN
# United Arab Emirates                      1.0                 1.0
# United Kingdom                            1.0                 1.0
# United States of America                  1.0                 1.0
# Uruguay                                   NaN                 NaN
# Uzbekistan                                NaN                 NaN
# Vanuatu                                   NaN                 NaN
# Venezuela                                 1.0                 NaN
# Vietnam                                   NaN                 NaN
# Virgin Islands (USA)                      NaN                 1.0
# Yemen                                     NaN                 1.0
# Zimbabwe                                  NaN                 NaN
#
#                           YouTubeTheNewBoston  AmountPerMonth
# CountryLive
# Afghanistan                               NaN        0.000000
# Albania                                   1.0        7.111111
# Algeria                                   1.0        0.000000
# Angola                                    NaN      116.666667
# Anguilla                                  NaN        0.000000
# Argentina                                 1.0       55.984444
# Australia                                 1.0      419.268452
# Austria                                   1.0      936.208333
# Azerbaijan                                NaN       25.555556
# Bahrain                                   NaN        0.000000
# Bangladesh                                1.0      239.361883
# Belarus                                   1.0       21.323854
# Belgium                                   1.0       53.774510
# Bosnia & Herzegovina                      1.0       19.807540
# Botswana                                  NaN        0.000000
# Brazil                                    1.0       56.239402
# Bulgaria                                  1.0       75.833333
# Cambodia                                  1.0       10.079365
# Cameroon                                  1.0        0.946970
# Canada                                    1.0      113.510961
# Cayman Islands                            NaN        0.000000
# Channel Islands                           1.0        0.000000
# Chile                                     1.0      300.416667
# China                                     1.0      236.441270
# Colombia                                  1.0       60.399660
# Costa Rica                                1.0       28.111111
# Croatia                                   1.0       31.674298
# Cuba                                      NaN        0.000000
# Cyprus                                    NaN       17.395833
# Czech Republic                            1.0       40.038767
# ...                                       ...             ...
# Senegal                                   1.0       80.595238
# Serbia                                    1.0       77.626263
# Singapore                                 1.0       51.618774
# Slovakia                                  NaN       29.738095
# Slovenia                                  1.0       18.425926
# Somalia                                   NaN      150.000000
# South Africa                              1.0       75.043561
# Spain                                     1.0      784.553084
# Sri Lanka                                 1.0       26.607143
# Sweden                                    1.0       35.413206
# Switzerland                               NaN       35.530045
# Taiwan                                    1.0      417.966524
# Thailand                                  1.0       11.166314
# Trinidad & Tobago                         NaN      500.000000
# Tunisia                                   NaN       18.000000
# Turkey                                    1.0       71.451613
# Turkmenistan                              NaN        0.000000
# Uganda                                    NaN      276.620370
# Ukraine                                   1.0       54.314874
# United Arab Emirates                      1.0       94.583333
# United Kingdom                            1.0       45.534443
# United States of America                  1.0      227.997996
# Uruguay                                   1.0        8.333333
# Uzbekistan                                1.0        3.333333
# Vanuatu                                   NaN        0.000000
# Venezuela                                 1.0       11.923077
# Vietnam                                   1.0      243.324074
# Virgin Islands (USA)                      NaN       60.416667
# Yemen                                     NaN    10000.000000
# Zimbabwe                                  1.0       23.125000
#
# [131 rows x 106 columns]

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)

Grouped_country.loc[["Canada", "United States of America","India","United Kingdom"]]

Top_4
# Out:
# CountryLive
# Canada                      113.510961
# United States of America    227.997996
# India                       135.100982
# United Kingdom               45.534443
# Name: AmountPerMonth, dtype: float64

# %% [markdown]
# We can see that UK and Cnada are spending far less than India on avergae per mnth. This seems odd knowing the difference between the relative socio-economic situations of these countries. Canada and UK have a far higher anual GDP per capita than india. So we have to look deeper to mae sure we do not have any outliers skewing our results.
#
# ## Slide 6 of 8
#
# We will look for some extream ouliers on these values. The best tool for spotting outliers that I know of is a box plot, so lets plot the boxes.

# %%
Set = df_interest_notnull2[df_interest_notnull2["CountryLive"].str.contains("United Kingdom|United States of America|India|Canada")]

Set_per_month = pd.DataFrame(data = {"CountryLive": Set["CountryLive"], "AmountPerMonth":Set["AmountPerMonth"]})

Set_per_month
# Out:
#        AmountPerMonth               CountryLive
# 1           13.333333  United States of America
# 2          200.000000  United States of America
# 6            0.000000            United Kingdom
# 15           0.000000  United States of America
# 16          16.666667  United States of America
# ...               ...                       ...
# 18107      275.000000                     India
# 18111      200.000000                     India
# 18113        0.000000  United States of America
# 18130        0.000000  United States of America
# 18156     1000.000000                     India
#
# [3915 rows x 2 columns]

# %%
# plotting

India = Set_per_month[Set_per_month["CountryLive"]== "India"]['AmountPerMonth'].tolist()
USA =  Set_per_month[Set_per_month["CountryLive"]== "United States of America"]['AmountPerMonth'].tolist()
UK = Set_per_month[Set_per_month["CountryLive"]== "UK"]['AmountPerMonth'].tolist()
Canada = Set_per_month[Set_per_month["CountryLive"]== "Canada"]['AmountPerMonth'].tolist()


data1 = [India, USA, Canada, UK]

fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data1)
lables = ['India','USA','UK','Canada']
ticks = [1,2,3,4]
ax1.set_xticks(ticks, minor=False)
ax1.set_xticklabels(lables, fontdict=None, minor=False)


plt.show()

# %%
fig2, ax2 = plt.subplots()
# Box plots to visualize distributions
import seaborn as sns
sns.boxplot(y = 'AmountPerMonth', x = 'CountryLive',
            data = Set_per_month)
plt.title('Money Spent Per Month Per Country\n(Distributions)',
         fontsize = 16)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['USA', 'UK', 'India', 'Canada']) # avoids tick labels overlap
plt.show()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %% [markdown]
# So there are a few outliers who seemingly live in the USA and spend more than $20,000 per month on learning software whch is extreamply unlikely. So we eliminate those rows that have AmountPerMonth>= 20000.

# %%
Set = Set[Set["AmountPerMonth"]<= 8000] #The two USA people, they are not working and not looking for work!


Grouped_country = Set.groupby(["CountryLive"]).mean()
Top_4 = Grouped_country["AmountPerMonth"].loc[["Canada", "United States of America","India","United Kingdom"]]
Top_4
# Out:
# CountryLive
# Canada                      113.510961
# United States of America    152.434378
# India                        65.758763
# United Kingdom               45.534443
# Name: AmountPerMonth, dtype: float64

# %%
Set[(Set["CountryLive"] == 'India') & (Set["AmountPerMonth"] >= 5000)]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  BootcampRecommend  ChildrenNumber                 CityPopulation  CodeEventConferences  CodeEventDjangoGirls  CodeEventFCC  CodeEventGameJam  CodeEventGirlDev  CodeEventHackathons  CodeEventMeetup  CodeEventNodeSchool  CodeEventNone CodeEventOther  CodeEventRailsBridge  CodeEventRailsGirls  CodeEventStartUpWknd  CodeEventWkdBootcamps  CodeEventWomenCode  CodeEventWorkshops       CommuteTime CountryCitizen  \
# 1728   24.0               0.0             NaN                NaN          NaN                NaN             NaN  between 100,000 and 1 million                   NaN                   NaN           NaN               1.0               NaN                  NaN              NaN                  NaN            NaN            NaN                   NaN                  NaN                   NaN                    NaN                 NaN                 NaN               NaN          India
# 7989   28.0               0.0             NaN                NaN          NaN                NaN             NaN  between 100,000 and 1 million                   1.0                   NaN           NaN               NaN               NaN                  NaN              NaN                  NaN            NaN            NaN                   NaN                  NaN                   NaN                    NaN                 NaN                 1.0  15 to 29 minutes          India
# 8126   22.0               0.0             NaN                NaN          NaN                NaN             NaN            more than 1 million                   NaN                   NaN           NaN               1.0               NaN                  1.0              NaN                  NaN            NaN            NaN                   NaN                  NaN                   NaN                    NaN                 NaN                 NaN               NaN          India
# 13398  19.0               0.0             NaN                NaN          NaN                NaN             NaN            more than 1 million                   NaN                   NaN           NaN               NaN               NaN                  NaN              NaN                  NaN            1.0            NaN                   NaN                  NaN                   NaN                    NaN                 NaN                 NaN               NaN          India
#
#       CountryLive              EmploymentField EmploymentFieldOther                    EmploymentStatus EmploymentStatusOther  ExpectedEarning  FinanciallySupporting  FirstDevJob Gender GenderOther  HasChildren  HasDebt  HasFinancialDependents  HasHighSpdInternet  HasHomeMortgage  HasServedInMilitary  HasStudentDebt  HomeMortgageOwe  HoursLearning                              ID.x                              ID.y    Income  IsEthnicMinority  IsReceiveDisabilitiesBenefits  IsSoftwareDev  \
# 1728        India                          NaN                  NaN  A stay-at-home parent or homemaker                   NaN          70000.0                    NaN          NaN   male         NaN          NaN      0.0                     0.0                 1.0              NaN                  0.0             NaN              NaN           30.0  d964ec629fd6d85a5bf27f7339f4fa6d  950a8cf9cef1ae6a15da470e572b1b7a       NaN               0.0                            0.0            0.0
# 7989        India  software development and IT                  NaN                  Employed for wages                   NaN         500000.0                    1.0          NaN   male         NaN          0.0      1.0                     1.0                 1.0              0.0                  0.0             1.0              NaN           20.0  a6a5597bbbc2c282386d6675641b744a  da7bbb54a8b26a379707be56b6c51e65  300000.0               0.0                            0.0            0.0
# 8126        India                          NaN                  NaN    Not working but looking for work                   NaN          80000.0                    NaN          NaN   male         NaN          NaN      1.0                     0.0                 1.0              0.0                  0.0             1.0              NaN           80.0  69e8ab9126baee49f66e3577aea7fd3c  9f08092e82f709e63847ba88841247c0       NaN               0.0                            0.0            0.0
# 13398       India                          NaN                  NaN                      Unable to work                   NaN         100000.0                    NaN          NaN   male         NaN          NaN      0.0                     0.0                 0.0              NaN                  0.0             NaN              NaN           30.0  b7fe7bc4edefc3a60eb48f977e4426e3  80ff09859ac475b70ac19b7b7369e953       NaN               0.0                            0.0            0.0
#
#        IsUnderEmployed                  JobApplyWhen  JobInterestBackEnd  JobInterestDataEngr  JobInterestDataSci  JobInterestDevOps  JobInterestFrontEnd  JobInterestFullStack  JobInterestGameDev  JobInterestInfoSec  JobInterestMobile JobInterestOther  JobInterestProjMngr  JobInterestQAEngr  JobInterestUX                               JobPref  JobRelocateYesNo                                    JobRoleInterest                        JobWherePref LanguageAtHome                    MaritalStatus  \
# 1728               NaN      Within the next 6 months                 1.0                  NaN                 NaN                NaN                  1.0                   NaN                 NaN                 NaN                1.0              NaN                  1.0                NaN            1.0                    work for a startup               1.0    User Experience Designer,   Mobile Developer...  in an office with other developers        Bengali            single, never married
# 7989               0.0  more than 12 months from now                 1.0                  NaN                 NaN                NaN                  1.0                   1.0                 1.0                 NaN                NaN              NaN                  NaN                NaN            1.0  work for a multinational corporation               1.0    User Experience Designer, Back-End Web Devel...  in an office with other developers        Marathi  married or domestic partnership
# 8126               NaN          I'm already applying                 1.0                  NaN                 NaN                NaN                  1.0                   1.0                 NaN                 NaN                NaN              NaN                  NaN                NaN            NaN                    work for a startup               1.0  Back-End Web Developer, Full-Stack Web Develop...  in an office with other developers      Malayalam            single, never married
# 13398              NaN             I haven't decided                 NaN                  NaN                 NaN                NaN                  NaN                   NaN                 NaN                 NaN                1.0              NaN                  NaN                NaN            NaN  work for a multinational corporation               1.0                                   Mobile Developer                       no preference          Hindi            single, never married
#
#        MoneyForLearning  MonthsProgramming   NetworkID         Part1EndTime       Part1StartTime         Part2EndTime       Part2StartTime  PodcastChangeLog  PodcastCodeNewbie  PodcastCodePen  PodcastDevTea  PodcastDotNET  PodcastGiantRobots  PodcastJSAir  PodcastJSJabber  PodcastNone                   PodcastOther  PodcastProgThrowdown  PodcastRubyRogues  PodcastSEDaily  PodcastSERadio  PodcastShopTalk  PodcastTalkPython  PodcastTheWebAhead  ResourceCodecademy  ResourceCodeWars  \
# 1728            20000.0                4.0  38d312a990  2017-03-10 10:22:34  2017-03-10 10:17:42  2017-03-10 10:24:38  2017-03-10 10:22:40               NaN                NaN             NaN            NaN            NaN                 NaN           1.0              NaN          NaN                            NaN                   NaN                NaN             NaN             NaN              NaN                NaN                 NaN                 1.0               NaN
# 7989             5000.0                1.0  c47a447b5d  2017-03-26 14:06:48  2017-03-26 14:02:41  2017-03-26 14:13:13  2017-03-26 14:07:17               NaN                NaN             NaN            NaN            NaN                 NaN           NaN              NaN          NaN  Not listened to anything yet.                   NaN                NaN             NaN             NaN              NaN                NaN                 NaN                 NaN               NaN
# 8126             5000.0                1.0  0d3d1762a4  2017-03-27 07:10:17  2017-03-27 07:05:23  2017-03-27 07:12:21  2017-03-27 07:10:22               NaN                NaN             NaN            NaN            NaN                 NaN           NaN              NaN          NaN                            NaN                   NaN                NaN             NaN             NaN              NaN                NaN                 NaN                 NaN               NaN
# 13398           20000.0                2.0  51a6f9a1a7  2017-04-01 00:31:25  2017-04-01 00:28:17  2017-04-01 00:33:44  2017-04-01 00:31:32               NaN                NaN             NaN            NaN            NaN                 NaN           NaN              NaN          NaN                            NaN                   NaN                NaN             NaN             NaN              NaN                NaN                 NaN                 NaN               NaN
#
#        ResourceCoursera  ResourceCSS  ResourceEdX  ResourceEgghead  ResourceFCC  ResourceHackerRank  ResourceKA  ResourceLynda  ResourceMDN  ResourceOdinProj ResourceOther  ResourcePluralSight  ResourceSkillcrush  ResourceSO  ResourceTreehouse  ResourceUdacity  ResourceUdemy  ResourceW3S       SchoolDegree                             SchoolMajor  StudentDebtOwe  YouTubeCodeCourse  YouTubeCodingTrain  YouTubeCodingTut360  YouTubeComputerphile  YouTubeDerekBanas  YouTubeDevTips  \
# 1728                NaN          NaN          NaN              NaN          NaN                 NaN         NaN            NaN          NaN               NaN           NaN                  NaN                 NaN         NaN                NaN              NaN            1.0          1.0  bachelor's degree                    Computer Programming             NaN                NaN                 NaN                  NaN                   NaN                NaN             NaN
# 7989                NaN          NaN          NaN              NaN          1.0                 NaN         NaN            1.0          NaN               NaN           NaN                  NaN                 NaN         NaN                NaN              NaN            NaN          NaN  bachelor's degree  Aerospace and Aeronautical Engineering          2500.0                NaN                 NaN                  NaN                   NaN                NaN             NaN
# 8126                NaN          1.0          NaN              1.0          NaN                 NaN         NaN            NaN          NaN               NaN           NaN                  NaN                 NaN         1.0                NaN              NaN            NaN          NaN  bachelor's degree  Electrical and Electronics Engineering         10000.0                NaN                 NaN                  NaN                   NaN                NaN             NaN
# 13398               NaN          NaN          NaN              NaN          NaN                 NaN         NaN            NaN          NaN               NaN           NaN                  NaN                 NaN         1.0                NaN              NaN            NaN          1.0  bachelor's degree                        Computer Science             NaN                NaN                 NaN                  NaN                   NaN                NaN             NaN
#
#        YouTubeEngineeredTruth  YouTubeFCC  YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  YouTubeSimplilearn  YouTubeTheNewBoston  AmountPerMonth
# 1728                      NaN         1.0                    NaN               NaN               NaN                 NaN         NaN                  NaN          NaN                 NaN                  NaN          5000.0
# 7989                      NaN         1.0                    NaN               NaN               NaN                 NaN         NaN                  NaN          NaN                 NaN                  NaN          5000.0
# 8126                      NaN         NaN                    NaN               1.0               NaN                 NaN         1.0                  NaN          NaN                 NaN                  1.0          5000.0
# 13398                     NaN         NaN                    NaN               NaN               NaN                 NaN         NaN                  NaN          NaN                 NaN                  NaN         10000.0

# %% [markdown]
# People in India spending more than 5000 a month. There are 4 of them, but none of them have done bootcams, two single two married, 2 f them have been programming for one month, one for 2 months and the last one for 4 months. All have bachelors degrees in STEM. I will drop them because they dont look right.

# %%
Set.drop(Set[(Set.CountryLive == 'India') & (Set.AmountPerMonth >= 3000)].index, inplace=True)



Set[Set.CountryLive=='India'].AmountPerMonth.plot() #checking to see if it has been eliminated

#checking to see the effect of this over the averages

# Grouped_country = Set.groupby(["CountryLive"]).mean()
# Top_4 = Grouped_country["AmountPerMonth"].loc[["Canada", "United States of America","India","United Kingdom"]]
# Top_4

# %%
#recomputing the mean values

Grouped_country = Set.groupby(["CountryLive"]).mean()
Top_4 = Grouped_country["AmountPerMonth"].loc[["Canada", "United States of America","India","United Kingdom"]]
Top_4
# Out:
# CountryLive
# Canada                      113.510961
# United States of America    183.800110
# India                        65.758763
# United Kingdom               45.534443
# Name: AmountPerMonth, dtype: float64

# %% [markdown]
# India droped from 135 to 81 by eliminating those 4 outliers. So now we know we havw to look at USA and Canada. But my solution does not look like thiers. I have not eliminated as many outliers. I found out that I can play with the monthly pay threshold and then drop the outliers and I get similar numbers, its just a tuning game at this point.
